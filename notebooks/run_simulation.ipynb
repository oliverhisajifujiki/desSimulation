# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

# Go to the parent of notebooks/, i.e. your project root
projectRoot = Path.cwd().parent
sys.path.append(str(projectRoot))

from src.simulator import (
    SimulationParams,
    initializePatient,
    simulateSinglePatientDeterministic,
)

# Initialize parameters
params = SimulationParams()

# Initialize a patient (you can tweak these values)
patient = initializePatient(
    severity=0.2,
    infection=0.2,
    respiratoryStress=0.1,
    advocacy=0.5,
)

# Run simulation
history = simulateSinglePatientDeterministic(
    initialState=patient,
    params=params,
    numSteps=5,
)

# Print results
for step in history:
    print(step)
# Out:
# {'step': 0, 'severity': 0.2, 'infection': 0.2, 'respiratoryStress': 0.1, 'advocacy': 0.5, 'treatment': 0, 'heartRate': 86.0, 'respiratoryRate': 17.400000000000002, 'temperature': 37.04, 'concernScore': 21.631999999999998}
# {'step': 1, 'severity': 0.22100000000000003, 'infection': 0.25, 'respiratoryStress': 0.122, 'advocacy': 0.5, 'treatment': 0, 'heartRate': 86.978, 'respiratoryRate': 17.616, 'temperature': 37.099999999999994, 'concernScore': 21.698839999999997}
# {'step': 2, 'severity': 0.24710000000000001, 'infection': 0.3, 'respiratoryStress': 0.14776, 'advocacy': 0.5, 'treatment': 0, 'heartRate': 88.0478, 'respiratoryRate': 17.874959999999998, 'temperature': 37.16, 'concernScore': 21.770952799999996}
# {'step': 3, 'severity': 0.278488, 'infection': 0.35, 'respiratoryStress': 0.17758600000000002, 'advocacy': 0.5, 'treatment': 0, 'heartRate': 89.212784, 'respiratoryRate': 18.179468, 'temperature': 37.22, 'concernScore': 21.84861312}
# {'step': 4, 'severity': 0.31536729999999996, 'infection': 0.39999999999999997, 'respiratoryStress': 0.21179528, 'advocacy': 0.5, 'treatment': 0, 'heartRate': 90.4766114, 'respiratoryRate': 18.53224088, 'temperature': 37.279999999999994, 'concernScore': 21.932111498399998}
